# %% [markdown]
# DataFrames

# %%
import numpy as np
import pandas as pd

# %%
## creating dataframe

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}

# %%
pd.DataFrame(data)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]

df2=pd.DataFrame(data_list)
df2
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
cols=['name','age','city','salary']
df2=pd.DataFrame(data_list,columns=cols)
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# Selection and indexing of columns

# %%
df2['name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: name, dtype: object

# %%
df2[['name','city']]
# Out:
#     name      city
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# Creating a new columns

# %%
df2['designation']=['doctor','eng','teacher','doctor']
df2
# Out:
#     name  age      city  salary designation
# 0   John   28  New York   65000      doctor
# 1   Anna   34     Paris   70000         eng
# 2  Peter   29    Berlin   62000     teacher
# 3  Linda   42    London   85000      doctor

# %% [markdown]
# Removing Columns

# %%
df2.drop('designation',axis=1) #sirf view deta hai
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
# df2.drop(["city","salary"],axis=1,inplace=True)
df2
# Out:
#     name  age      city  salary designation
# 0   John   28  New York   65000      doctor
# 1   Anna   34     Paris   70000         eng
# 2  Peter   29    Berlin   62000     teacher
# 3  Linda   42    London   85000      doctor

# %%
df2.drop(0,axis=0)
# Out:
#     name  age    city  salary designation
# 1   Anna   34   Paris   70000         eng
# 2  Peter   29  Berlin   62000     teacher
# 3  Linda   42  London   85000      doctor

# %% [markdown]
# Selecting row

# %%
df2.loc[0]
# Out:
# name               John
# age                  28
# city           New York
# salary            65000
# designation      doctor
# Name: 0, dtype: object

# %%
df2.loc[[0,1]]
# Out:
#    name  age      city  salary designation
# 0  John   28  New York   65000      doctor
# 1  Anna   34     Paris   70000         eng

# %%
df2.iloc[3]
# Out:
# name            Linda
# age                42
# city           London
# salary          85000
# designation    doctor
# Name: 3, dtype: object

# %% [markdown]
# Selecting subsets of rows and columns

# %%
df2.loc[[0,1]][['city','salary']]
# Out:
#        city  salary
# 0  New York   65000
# 1     Paris   70000

# %% [markdown]
# Conditional selection

# %%
df2
# Out:
#     name  age      city  salary designation
# 0   John   28  New York   65000      doctor
# 1   Anna   34     Paris   70000         eng
# 2  Peter   29    Berlin   62000     teacher
# 3  Linda   42    London   85000      doctor

# %%
##wants to see those people whose age is above 30
df2[df2['age']>30]
# Out:
#     name  age    city  salary designation
# 1   Anna   34   Paris   70000         eng
# 3  Linda   42  London   85000      doctor

# %%
## want only people whose age is greater than 30 and belongs to paris
df2[(df2['age']>30 ) & (df2['city']=='Paris')]
# Out:
#    name  age   city  salary designation
# 1  Anna   34  Paris   70000         eng
